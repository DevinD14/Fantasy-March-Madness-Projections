# %% [markdown]
# # 🏀 March Madness Fantasy Basketball Projections
# **Pipeline:** RealGM stats CSV → Fantasy PPG → Monte Carlo expected games → Ranked draft board
#
# ---
#
# ## 📋 Before You Start — Build Your RealGM CSV
#
#
# **Steps:**
# 1. Go to the RealGM NCAA stats page:
#    👉 https://basketball.realgm.com/ncaa/stats/2026/Averages/Qualified/All/Conference_Regular_Season/All/points/desc/1/
# 2. Select and copy all **data rows** from the table (skip the header row)
# 3. Paste into Excel or Google Sheets
# 4. Navigate to page 2, copy rows, paste below — repeat through all 26 pages
# 5. Add this as the **very first row** of your spreadsheet:
#    ```
#    Rank,Player,Team,GP,MPG,PPG,FGM,FGA,FG%,3PM,3PA,3P%,FTM,FTA,FT%,ORB,DRB,RPG,APG,SPG,BPG,TOV,PF
#    ```
# 6. Export/save as **`realgm_stats.csv`** in the same folder as this notebook
#
# > ⚠️ RealGM uses short team **abbreviations** (e.g. `AUB`, `DUKE`, `BYU`) instead of full names.
# > The notebook handles this automatically using a lookup table.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import re
from difflib import SequenceMatcher
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\devin\AppData\Local\Temp\ipykernel_40608\1508623480.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# Fantasy scoring weights
scoring = {
    'PPG': 1.0,
    'RPG': 1.0,
    'APG': 1.0,
    # 'SPG': 2.0,
    # 'BPG': 2.0,
    # '3PM': 0.5,
}

# Player stats filename
stats_file = 'realgm_stats.csv'

# Path to your Monte Carlo CSV/Excel file
# Expected format: two columns — 'Team' and 'ExpectedGames'
monte_carlo_file = 'expected_games.csv'

# Minimum games and minutes per game to include a player
min_games = 5
min_mpg = 10

# How many players to show in the final draft board
draft_board_size = 150

# %%
# real GM team abbreviations mapped to team name
# add new entries as needed
realgm_abbrev = {
    'AIRF':   'Air Force',
    'ALA':    'Alabama',
    'ALCN':   'Alcorn State',
    'ALST':   'Alabama State',
    'AMER':   'American',
    'ARIZ':   'Arizona',
    'ARZ':   'Arizona',
    'ARK':    'Arkansas',
    'ARST':   'Arkansas-Pine Bluff',
    'ASU':    'Arizona State',
    'AUB':    'Auburn',
    'BAY':    'Baylor',
    'BC':     'Boston College',
    'BCST':   'Bethune-Cookman',
    'BOIS':   'Boise State',
    'BRY':    'Bryant',
    'BUF':    'Buffalo',
    'BYU':    'BYU',
    'CHAT':   'Chattanooga',
    'CIN':    'Cincinnati',
    'CLEM':   'Clemson',
    'COLG':   'Colgate',
    'COLO':   'Colorado',
    'COPN':   'Coppin State',
    'COST':   'Colorado State',
    'CREI':   'Creighton',
    'CSU':    'Colorado State',
    'DAVI':   'Davidson',
    'DAY':    'Dayton',
    'DELT':   'Delaware State',
    'DRAKE':  'Drake',
    'DUKE':   'Duke',
    'ETSU':   'East Tennessee State',
    'FLA':    'Florida',
    'FLAM':   'Florida A&M',
    'FRES':   'Fresno State',
    'FURD':   'Fordham',
    'FURM':   'Furman',
    'GONZ':   'Gonzaga',
    'GRAM':   'Grambling',
    'GW':     'George Washington',
    'HAW':    'Hawaii',
    'HOUS':   'Houston',
    'HOW':    'Howard',
    'HP':     'High Point',
    'HPT':    'High Point',
    'IAST':   'Iowa State',
    'ILL':    'Illinois',
    'IND':    'Indiana',
    'IOWA':   'Iowa',
    'IWAST':  'Iowa State',
    'JKSN':   'Jackson State',
    'JMU':    'James Madison',
    'KAN':    'Kansas',
    'KANS':   'Kansas',
    'KAST':   'Kansas State',
    'KEN':    'Kentucky',
    'KU':     'Kansas',
    'LIB':    'Liberty',
    'LIP':    'Lipscomb',
    'LMU':    'Loyola Marymount',
    'LONG':   'Longwood',
    'LOU':    'Louisville',
    'LSU':    'LSU',
    'LVILL':  'Louisville',
    'MARQ':   'Marquette',
    'MCN':    'McNeese',
    'MD':     'Maryland',
    'MEM':    'Memphis',
    'MERR':   'Merrimack',
    'MICH':   'Michigan',
    'MINN':   'Minnesota',
    'MISS':   'Ole Miss',
    'MIZ':    'Missouri',
    'MONT':   'Montana',
    'MORE':   'Morehead State',
    'MORG':   'Morgan State',
    'MSM':    "Mount St. Mary's",
    'MSST':   'Mississippi State',
    'MCHST':    'Michigan State',
    'MVST':   'Mississippi Valley State',
    'MZZOU':  'Missouri',
    'NCAT':   'North Carolina A&T',
    'NCST':   'NC State',
    'ND':     'Notre Dame',
    'NEB':    'Nebraska',
    'NFST':   'Norfolk State',
    'NMST':   'New Mexico State',
    'NOVA':   'Villanova',
    'NW':     'Northwestern',
    'NWST':   'Northwestern',
    'OKLA':   'Oklahoma',
    'OKST':   'Oklahoma State',
    'ORAL':   'Oral Roberts',
    'ORE':    'Oregon',
    'OSU':    'Ohio State',
    'PACF':   'Pacific',
    'PENN':   'Penn State',
    'PEPP':   'Pepperdine',
    'PITT':   'Pittsburgh',
    'PORT':   'Portland',
    'PRST':   'Prairie View A&M',
    'PUR':    'Purdue',
    'PURD':   'Purdue',
    'RICH':   'Richmond',
    'RMU':    'Robert Morris',
    'RUTG':   'Rutgers',
    'SAMF':   'Samford',
    'SCST':   'South Carolina State',
    'SCU':    'Santa Clara',
    'SDST':   'San Diego State',
    'SDSU':   'San Diego State',
    'SEAT':   'Seattle',
    'SFU':    'Saint Francis',
    'SIUE':   'SIU Edwardsville',
    'SJST':   'San Jose State',
    'SMCA':   "Saint Mary's",
    'STMRY':  "Saint Mary's",
    'STJ': "St. John's (NY)",
    'SUST':   'Southern',
    'SYRA':   'Syracuse',
    'TCU':    'TCU',
    'TENN':   'Tennessee',
    'TEX':    'Texas',
    'TROY':   'Troy',
    'TTU':    'Texas Tech',
    'TXAM':   'Texas A&M',
    'TXSO':   'Texas Southern',
    'TXST':   'Texas State',
    'TXTCH':  'Texas Tech',
    'UA':     'Alabama',
    'UCF':    'UCF',
    'UCI':    'UC Irvine',
    'UCLA':   'UCLA',
    'UCON':   'UConn',
    'UConn':   'Connecticut',
    'UCSB':   'UC Santa Barbara',
    'UCSD':   'UC San Diego',
    'UGA':    'Georgia',
    'UK':     'Kentucky',
    'UNC':    'North Carolina',
    'UNL': 'Nebraska',
    'UNLV':   'UNLV',
    'UNM':    'New Mexico',
    'UNR':    'Nevada',
    'USC':    'USC',
    'USD':    'San Diego',
    'USF':    'South Florida',
    'USU':    'Utah State',
    'UTAH':   'Utah',
    'UVA':   'Virginia',
    'U OF H': 'Houston',
    'U of H': 'Houston',
    'U OF T': 'Toledo',
    'U of T': 'Toledo',
    'UWISC':  'Wisconsin',
    'VAN':    'Vanderbilt',
    'VANDY':  'Vanderbilt',
    'VCU':    'VCU',
    'VILL':   'Villanova',
    'WASH':   'Washington',
    'WEST':   'Western Carolina',
    'WF':     'Wake Forest',
    'WIS':    'Wisconsin',
    'WOF':    'Wofford',
    'WSU':    'Washington State',
    'WVU':    'West Virginia',
    'WYO':    'Wyoming',
    'XAV':    'Xavier',
    'YALE':   'Yale',
    'ZAGS':   'Gonzaga',
}

# %%
with open(stats_file, 'r', encoding='utf-8-sig') as f:
    first_line = f.readline()
delimiter = '\t' if first_line.count('\t') > first_line.count(',') else ','

raw = pd.read_csv(stats_file, sep=delimiter, dtype=str)
raw.columns = raw.columns.str.strip()

raw = raw.loc[:, ~raw.columns.str.match(r'^(Unnamed|#|Rank|Rk)$', case=False)]

col_map = {
    'G': 'GP', 'MIN': 'MPG', 'PTS': 'PPG', 'REB': 'RPG', 'TRB': 'RPG',
    'AST': 'APG', 'STL': 'SPG', 'BLK': 'BPG', '3P': '3PM',
}
raw = raw.rename(columns={c: col_map[c] for c in raw.columns if c in col_map})

if 'Player' in raw.columns:
    raw = raw[~raw['Player'].astype(str).str.strip().isin(['Player', '#', 'Rank', ''])]

for col in [c for c in raw.columns if c not in ('Player', 'Team')]:
    raw[col] = pd.to_numeric(raw[col], errors='coerce')

raw['Player'] = raw['Player'].astype(str).str.strip()
raw['Team'] = raw['Team'].astype(str).str.strip()
raw.dropna(subset=['Player', 'Team'], inplace=True)
raw.drop_duplicates(subset=['Player', 'Team'], inplace=True)
raw.reset_index(drop=True, inplace=True)

print(f'{len(raw):,} players loaded')
# Out:
# 2,583 players loaded

# %%
abbrev_ci = {k.upper(): v for k, v in realgm_abbrev.items()}
raw['team_full'] = raw['Team'].str.upper().map(abbrev_ci)

unknown = raw[raw['team_full'].isna()]['Team'].unique()
if len(unknown) > 0:
    print(f'{len(unknown)} unknown abbreviation(s) — add to realgm_abbrev:')
    for abbr in sorted(unknown):
        count = (raw['Team'] == abbr).sum()
        
else:
    print('all abbreviations resolved')

raw = raw.rename(columns={'Team': 'team_abbrev'})
raw['Team'] = raw['team_full'].fillna(raw['team_abbrev'])
raw.drop(columns='team_full', inplace=True)

raw[['Player', 'team_abbrev', 'Team']].head()
# Out:
# 279 unknown abbreviation(s) — add to realgm_abbrev:
#               Player team_abbrev           Team
# 0     Daeshun Ruffin        JKSN  Jackson State
# 1      A.J. Dybantsa         BYU            BYU
# 2       Jordan Riley        ECAR           ECAR
# 3  Darius Acuff, Jr.         ARK       Arkansas
# 4       Dontae Horne       PVAMU          PVAMU

# %%
def load_mc(path):
    mc = pd.read_excel(path) if path.lower().endswith(('xlsx', 'xls')) else pd.read_csv(path)
    mc.columns = mc.columns.str.strip()
    remap = {}
    for c in mc.columns:
        cl = c.lower().replace(' ', '_')
        if cl in ('team', 'school', 'program'):
            remap[c] = 'Team'
        elif cl in ('expected_games', 'exp_games', 'expectedgames', 'games', 'avg_games', 'projected_games'):
            remap[c] = 'ExpectedGames'
        elif cl in ('seed', 'seeding'):
            remap[c] = 'Seed'
    mc = mc.rename(columns=remap)
    for req in ('Team', 'ExpectedGames'):
        if req not in mc.columns:
            raise ValueError(f"missing column '{req}', found: {mc.columns.tolist()}")
    mc['ExpectedGames'] = pd.to_numeric(mc['ExpectedGames'], errors='coerce')
    mc['Team'] = mc['Team'].astype(str).str.strip()
    return mc

def normalize(name):
    name = re.sub(r'[^a-z0-9 ]', ' ', name.lower())
    return re.sub(r'\s+', ' ', name).strip()

mc_df = load_mc(monte_carlo_file)
print(f'{len(mc_df)} teams  |  xGames range: {mc_df.ExpectedGames.min():.2f} – {mc_df.ExpectedGames.max():.2f}')

expanded_teams = list(raw['Team'].unique())
expanded_lower = {t.lower(): t for t in expanded_teams}
expanded_norm  = {normalize(t): t for t in expanded_teams}

auto_fixed = {}
still_missing = []

for team in mc_df['Team']:
    if team.lower() in expanded_lower:
        if expanded_lower[team.lower()] != team:
            auto_fixed[team] = expanded_lower[team.lower()]
    elif normalize(team) in expanded_norm:
        auto_fixed[team] = expanded_norm[normalize(team)]
    else:
        still_missing.append(team)

if auto_fixed:
    mc_df['Team'] = mc_df['Team'].replace(auto_fixed)
    print(f'\nauto-resolved {len(auto_fixed)} name difference(s):')
    for old, new in auto_fixed.items():
        print(f'  "{old}" → "{new}"')

if still_missing:
    print(f'\ncould not match {len(still_missing)} team(s):')
    for t in still_missing:
        scored = sorted([(SequenceMatcher(None, normalize(t), normalize(e)).ratio(), e) for e in expanded_teams], reverse=True)[:3]
        sugg = [f'"{e}" ({r:.2f})' for r, e in scored if r > 0.5]
        print(f'  "{t}" → suggestions: {sugg or "none"}')
    print('\nadd the abbrev to realgm_abbrev and re-run')
else:
    print('\nall MC teams matched')
# Out:
# 64 teams  |  xGames range: 1.00 – 4.70
#
# auto-resolved 2 name difference(s):
#   "Siena" → "SIENA"
#   "Idaho" → "IDAHO"
#
# could not match 23 team(s):
#   "California Baptist" → suggestions: ['"Arizona State" (0.52)']
#   "Northern Iowa" → suggestions: ['"North Carolina" (0.59)', '"Notre Dame" (0.52)']
#   "North Dakota State" → suggestions: ['"Ohio State" (0.64)', '"Oklahoma State" (0.62)', '"San Diego State" (0.61)']
#   "South Florida" → suggestions: ['"Florida" (0.70)', '"North Carolina" (0.52)']
#   "Furman" → suggestions: ['"FRMN" (0.80)', '"MAN" (0.67)', '"USMA" (0.60)']
#   "Lehigh" → suggestions: ['"LEHI" (0.80)', '"Creighton" (0.53)']
#   "McNeese State" → suggestions: ['"Texas State" (0.67)', '"NC State" (0.67)', '"Michigan State" (0.67)']
#   "Pennsylvania" → suggestions: ['"Penn State" (0.55)']
#   "Virginia Commonwealth" → suggestions: ['"Virginia" (0.55)']
#   "Saint Mary's (CA)" → suggestions: ['"Saint Mary\'s" (0.89)', '"Santa Clara" (0.62)', '"UC Santa Barbara" (0.52)']
#   "Texas A&M" → suggestions: ['"TEXAS" (0.71)', '"Texas State" (0.70)', '"Texas Tech" (0.63)']
#   "Long Island University" → suggestions: none
#   "Kennesaw State" → suggestions: ['"Penn State" (0.75)', '"East Tennessee State" (0.65)', '"Texas State" (0.64)']
#   "Brigham Young" → suggestions: ['"Richmond" (0.57)', '"Creighton" (0.55)', '"High Point" (0.52)']
#   "Miami (FL)" → suggestions: ['"MIAMI" (0.77)']
#   "Queens (NC)" → suggestions: none
#   "Maryland-Baltimore County" → suggestions: none
#   "Saint Louis" → suggestions: ['"STLOU" (0.62)', '"Saint Mary\'s" (0.61)', '"Santa Clara" (0.55)']
#   "Hofstra" → suggestions: ['"HOF" (0.60)', '"Ohio State" (0.59)', '"Houston" (0.57)']
#   "Akron" → suggestions: ['"AKR" (0.75)', '"Arizona" (0.67)', '"Dayton" (0.55)']
#   "Wright State" → suggestions: ['"Washington State" (0.71)', '"Arizona State" (0.64)', '"Utah State" (0.64)']
#   "Southern Methodist" → suggestions: ['"Robert Morris" (0.52)']
#   "Tennessee State" → suggestions: ['"East Tennessee State" (0.86)', '"Tennessee" (0.75)', '"Penn State" (0.72)']
#
# add the abbrev to realgm_abbrev and re-run

# %%
df = raw.copy()

if 'MPG' in df.columns:
    df = df[df['MPG'] >= min_mpg]
if 'GP' in df.columns:
    df = df[df['GP'] >= min_games]

tourney_teams = set(mc_df['Team'].str.lower())
df['_key'] = df['Team'].str.lower().str.strip()
tourney = df[df['_key'].isin(tourney_teams)].drop(columns='_key').copy()

print(f'{len(raw):,} → {len(df):,} after stat filters → {len(tourney):,} tournament players across {tourney["Team"].nunique()} teams')

empty = [t for t in mc_df['Team'] if t.lower() not in set(tourney['Team'].str.lower())]
if empty:
    print(f'\nno players matched for: {empty}')
    print('probably still a name mismatch — check cell 6')

tourney.head(5)
# Out:
# 2,583 → 2,552 after stat filters → 301 tournament players across 41 teams
#
# no players matched for: ['California Baptist', 'Northern Iowa', 'North Dakota State', 'South Florida', 'Furman', 'Lehigh', 'McNeese State', 'Pennsylvania', 'Virginia Commonwealth', "Saint Mary's (CA)", 'Texas A&M', 'Long Island University', 'Kennesaw State', 'Brigham Young', 'Miami (FL)', 'Queens (NC)', 'Maryland-Baltimore County', 'Saint Louis', 'Hofstra', 'Akron', 'Wright State', 'Southern Methodist', 'Tennessee State']
# probably still a name mismatch — check cell 6
#                Player team_abbrev  GP   MPG   PPG  FGM   FGA    FG%  3:00 PM  \
# 3   Darius Acuff, Jr.         ARK  17  36.5  24.8  8.5  17.4  0.492      2.5
# 15     Cameron Boozer        DUKE  18  33.9  22.7  7.9  13.4  0.593      1.6
# 17        J.T. Toppin       TXTCH  13  35.7  22.6  9.6  17.8  0.541      0.9
# 20     Bennett Stirtz        IOWA  20  38.4  22.2  7.8  15.5  0.500      2.8
# 25         Graham Ike        ZAGS  15  32.3  21.9  8.9  14.5  0.613      1.0
#
#     3PA  ...    FT%  ORB  DRB   RPG  APG  SPG  BPG  TOV   PF        Team
# 3   5.7  ...  0.826  0.4  2.6   3.0  6.6  0.7  0.4  2.1  1.5    Arkansas
# 15  3.5  ...  0.795  3.4  6.9  10.3  3.9  1.6  0.2  2.3  1.3        Duke
# 17  2.6  ...  0.780  3.8  7.3  11.1  2.4  1.5  1.8  2.3  2.5  Texas Tech
# 20  7.5  ...  0.839  0.2  2.2   2.4  3.8  1.4  0.3  2.2  2.3        Iowa
# 25  2.7  ...  0.762  2.3  5.9   8.2  2.1  1.0  1.0  2.0  2.6     Gonzaga
#
# [5 rows x 23 columns]

# %%
missing = [s for s in scoring if s not in tourney.columns]
if missing:
    raise ValueError(f'scoring columns not in data: {missing}')

tourney['FPPG'] = tourney.apply(
    lambda r: sum(float(r.get(s, 0) or 0) * w for s, w in scoring.items()), axis=1
).round(2)

print(f'formula: {" + ".join(f"{w}×{s}" for s, w in scoring.items())}')
print()
cols = ['Player', 'Team', 'GP', 'MPG'] + list(scoring.keys()) + ['FPPG']
tourney.nlargest(10, 'FPPG')[[c for c in cols if c in tourney.columns]]
# Out:
# formula: 1.0×PPG + 1.0×RPG + 1.0×APG
#                       Player            Team  GP   MPG   PPG   RPG  APG  FPPG
# 15            Cameron Boozer            Duke  18  33.9  22.7  10.3  3.9  36.9
# 17               J.T. Toppin      Texas Tech  13  35.7  22.6  11.1  2.4  36.1
# 3          Darius Acuff, Jr.        Arkansas  17  36.5  24.8   3.0  6.6  34.4
# 25                Graham Ike         Gonzaga  15  32.3  21.9   8.2  2.1  32.2
# 53              Caleb Wilson  North Carolina  11  33.5  20.1   7.7  3.1  30.9
# 28              Tyler Tanner      Vanderbilt  18  36.2  21.5   3.4  5.5  30.4
# 132  Christian Anderson, Jr.      Texas Tech  17  39.2  18.1   3.8  8.3  30.2
# 43                 Nick Boyd       Wisconsin  20  32.9  20.8   3.9  4.5  29.2
# 59             Keaton Wagler        Illinois  20  35.5  19.9   4.4  4.9  29.2
# 65            Bruce Thornton      Ohio State  20  36.7  19.7   5.4  4.1  29.2

# %%
mc_m = mc_df.copy()
mc_m['_key'] = mc_m['Team'].str.lower().str.strip()
tourney['_key'] = tourney['Team'].str.lower().str.strip()
seed_cols = ['Seed'] if 'Seed' in mc_m.columns else []

proj = tourney.merge(
    mc_m[['_key', 'ExpectedGames'] + seed_cols], on='_key', how='left'
).drop(columns='_key')

proj['ProjectedFP'] = (proj['FPPG'] * proj['ExpectedGames']).round(2)
print(f'{len(proj)} players with projections')
proj[['Player', 'Team', 'FPPG', 'ExpectedGames', 'ProjectedFP']].head(5)
# Out:
# 301 players with projections
#               Player        Team  FPPG  ExpectedGames  ProjectedFP
# 0  Darius Acuff, Jr.    Arkansas  34.4         2.8161        96.87
# 1     Cameron Boozer        Duke  36.9         4.6803       172.70
# 2        J.T. Toppin  Texas Tech  36.1         2.4408        88.11
# 3     Bennett Stirtz        Iowa  28.4         1.7464        49.60
# 4         Graham Ike     Gonzaga  32.2         3.2845       105.76

# %%
cols = (
    (['Seed'] if 'Seed' in proj.columns else []) +
    ['Player', 'Team', 'team_abbrev', 'GP', 'MPG'] +
    list(scoring.keys()) +
    ['FPPG', 'ExpectedGames', 'ProjectedFP']
)
cols = [c for c in cols if c in proj.columns]

draft_board = (
    proj[cols]
    .sort_values('ProjectedFP', ascending=False)
    .head(draft_board_size)
    .reset_index(drop=True)
)
draft_board.index += 1
draft_board.index.name = 'Rank'

fmt = {k: '{:.2f}' for k in ['FPPG', 'ExpectedGames', 'ProjectedFP'] if k in draft_board.columns}
styled = draft_board.style.set_caption('🏀 March Madness Fantasy Draft Board')
for col, cmap in [('ProjectedFP', 'YlGn'), ('FPPG', 'Blues'), ('ExpectedGames', 'Oranges')]:
    if col in draft_board.columns:
        styled = styled.background_gradient(subset=[col], cmap=cmap)
display(styled.format(fmt))
# Out:
# <style type="text/css">
# #T_e4d04_row0_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e4d04_row0_col10, #T_e4d04_row15_col10, #T_e4d04_row25_col10, #T_e4d04_row44_col10, #T_e4d04_row70_col10, #T_e4d04_row78_col10, #T_e4d04_row90_col10, #T_e4d04_row131_col10 {
#   background-color: #802704;
#   color: #f1f1f1;
# }
# #T_e4d04_row0_col11 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e4d04_row1_col9, #T_e4d04_row9_col9 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_e4d04_row1_col10, #T_e4d04_row3_col10, #T_e4d04_row13_col10, #T_e4d04_row18_col10, #T_e4d04_row64_col10, #T_e4d04_row72_col10, #T_e4d04_row74_col10, #T_e4d04_row97_col10 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_e4d04_row1_col11 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_e4d04_row2_col9, #T_e4d04_row39_col9 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_e4d04_row2_col10, #T_e4d04_row14_col10, #T_e4d04_row16_col10, #T_e4d04_row19_col10, #T_e4d04_row22_col10, #T_e4d04_row32_col10, #T_e4d04_row100_col10 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_e4d04_row2_col11 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_e4d04_row3_col9, #T_e4d04_row65_col9 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_e4d04_row3_col11 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_e4d04_row4_col9 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_e4d04_row4_col10, #T_e4d04_row30_col10, #T_e4d04_row67_col10, #T_e4d04_row95_col10, #T_e4d04_row102_col10, #T_e4d04_row108_col10, #T_e4d04_row115_col10, #T_e4d04_row135_col10 {
#   background-color: #f67723;
#   color: #f1f1f1;
# }
# #T_e4d04_row4_col11 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_e4d04_row5_col9, #T_e4d04_row38_col9, #T_e4d04_row88_col9 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_e4d04_row5_col10, #T_e4d04_row24_col10, #T_e4d04_row42_col10, #T_e4d04_row45_col10, #T_e4d04_row59_col10, #T_e4d04_row121_col10, #T_e4d04_row127_col10, #T_e4d04_row136_col10 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_e4d04_row5_col11 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_e4d04_row6_col9 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_e4d04_row6_col10, #T_e4d04_row26_col10, #T_e4d04_row31_col10, #T_e4d04_row93_col10, #T_e4d04_row113_col10, #T_e4d04_row122_col10 {
#   background-color: #e45709;
#   color: #f1f1f1;
# }
# #T_e4d04_row6_col11 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_e4d04_row7_col9 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_e4d04_row7_col10, #T_e4d04_row9_col10, #T_e4d04_row10_col10, #T_e4d04_row33_col10, #T_e4d04_row34_col10, #T_e4d04_row82_col10 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_e4d04_row7_col11 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_e4d04_row8_col9, #T_e4d04_row23_col9, #T_e4d04_row29_col9, #T_e4d04_row79_col9, #T_e4d04_row94_col9 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_e4d04_row8_col10, #T_e4d04_row20_col10, #T_e4d04_row53_col10, #T_e4d04_row68_col10, #T_e4d04_row106_col10 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_e4d04_row8_col11, #T_e4d04_row9_col11 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_e4d04_row10_col9 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_e4d04_row10_col11 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_e4d04_row11_col9 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_e4d04_row11_col10, #T_e4d04_row37_col10, #T_e4d04_row49_col10, #T_e4d04_row51_col10, #T_e4d04_row85_col10 {
#   background-color: #eb600e;
#   color: #f1f1f1;
# }
# #T_e4d04_row11_col11, #T_e4d04_row12_col11 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_e4d04_row12_col9 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_e4d04_row12_col10, #T_e4d04_row57_col10, #T_e4d04_row60_col10, #T_e4d04_row80_col10, #T_e4d04_row101_col10 {
#   background-color: #fd9e54;
#   color: #000000;
# }
# #T_e4d04_row13_col9, #T_e4d04_row76_col9, #T_e4d04_row77_col9 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e4d04_row13_col11 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_e4d04_row14_col9 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_e4d04_row14_col11 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_e4d04_row15_col9, #T_e4d04_row19_col9, #T_e4d04_row75_col9, #T_e4d04_row123_col9 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_e4d04_row15_col11 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_e4d04_row16_col9 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e4d04_row16_col11 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_e4d04_row17_col9 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_e4d04_row17_col10, #T_e4d04_row35_col10, #T_e4d04_row96_col10, #T_e4d04_row107_col10, #T_e4d04_row116_col10 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_e4d04_row17_col11 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_e4d04_row18_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_e4d04_row18_col11 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_e4d04_row19_col11 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_e4d04_row20_col9, #T_e4d04_row43_col9, #T_e4d04_row146_col9 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_e4d04_row20_col11 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_e4d04_row21_col9 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_e4d04_row21_col10, #T_e4d04_row62_col10, #T_e4d04_row99_col10, #T_e4d04_row103_col10, #T_e4d04_row104_col10, #T_e4d04_row114_col10 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_e4d04_row21_col11 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_e4d04_row22_col9, #T_e4d04_row89_col9 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_e4d04_row22_col11, #T_e4d04_row23_col11 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_e4d04_row23_col10, #T_e4d04_row47_col10, #T_e4d04_row71_col10, #T_e4d04_row87_col10, #T_e4d04_row143_col10 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_e4d04_row24_col9, #T_e4d04_row30_col9 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_e4d04_row24_col11, #T_e4d04_row25_col11 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_e4d04_row25_col9, #T_e4d04_row67_col9, #T_e4d04_row105_col9 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_e4d04_row26_col9, #T_e4d04_row60_col9, #T_e4d04_row62_col9, #T_e4d04_row126_col9, #T_e4d04_row137_col9 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_e4d04_row26_col11 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_e4d04_row27_col9, #T_e4d04_row128_col9 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_e4d04_row27_col10, #T_e4d04_row28_col10, #T_e4d04_row48_col10, #T_e4d04_row63_col10, #T_e4d04_row69_col10 {
#   background-color: #f87f2c;
#   color: #f1f1f1;
# }
# #T_e4d04_row27_col11 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_e4d04_row28_col9, #T_e4d04_row52_col9 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_e4d04_row28_col11 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_e4d04_row29_col10, #T_e4d04_row50_col10, #T_e4d04_row55_col10, #T_e4d04_row75_col10, #T_e4d04_row81_col10 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_e4d04_row29_col11 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_e4d04_row30_col11 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_e4d04_row31_col9 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_e4d04_row31_col11, #T_e4d04_row32_col11, #T_e4d04_row33_col11 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_e4d04_row32_col9, #T_e4d04_row99_col9 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_e4d04_row33_col9 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_e4d04_row34_col9, #T_e4d04_row42_col9, #T_e4d04_row71_col9, #T_e4d04_row80_col9, #T_e4d04_row84_col9 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_e4d04_row34_col11, #T_e4d04_row35_col11 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_e4d04_row35_col9 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_e4d04_row36_col9 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_e4d04_row36_col10, #T_e4d04_row39_col10

# %%
if 'Seed' not in proj.columns:
    print('no Seed column in MC file, skipping sleeper board')
else:
    sleeper_pool = proj[proj['Seed'].notna() & (proj['Seed'].astype(float) >= 8)]

    cols = (
        ['Seed', 'Player', 'Team', 'team_abbrev', 'GP', 'MPG'] +
        list(scoring.keys()) +
        ['FPPG', 'ExpectedGames', 'ProjectedFP']
    )
    cols = [c for c in cols if c in sleeper_pool.columns]

    sleeper_board = (
        sleeper_pool[cols]
        .sort_values('ProjectedFP', ascending=False)
        .head(draft_board_size)
        .reset_index(drop=True)
    )
    sleeper_board.index += 1
    sleeper_board.index.name = 'Rank'

    fmt = {k: '{:.2f}' for k in ['FPPG', 'ExpectedGames', 'ProjectedFP'] if k in sleeper_board.columns}
    styled = sleeper_board.style.set_caption('🎯 Sleeper Board — Seeds 8+')
    for col, cmap in [('ProjectedFP', 'YlGn'), ('FPPG', 'Blues'), ('ExpectedGames', 'Oranges')]:
        if col in sleeper_board.columns:
            styled = styled.background_gradient(subset=[col], cmap=cmap)
    display(styled.format(fmt))
# Out:
# <style type="text/css">
# #T_355c6_row0_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_355c6_row0_col10, #T_355c6_row3_col10, #T_355c6_row6_col10, #T_355c6_row31_col10, #T_355c6_row33_col10 {
#   background-color: #832804;
#   color: #f1f1f1;
# }
# #T_355c6_row0_col11 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_355c6_row1_col9 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_355c6_row1_col10, #T_355c6_row20_col10, #T_355c6_row47_col10, #T_355c6_row56_col10, #T_355c6_row60_col10, #T_355c6_row76_col10, #T_355c6_row89_col10, #T_355c6_row93_col10 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_355c6_row1_col11 {
#   background-color: #004c2c;
#   color: #f1f1f1;
# }
# #T_355c6_row2_col9 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_355c6_row2_col10, #T_355c6_row18_col10, #T_355c6_row37_col10, #T_355c6_row39_col10, #T_355c6_row50_col10, #T_355c6_row54_col10, #T_355c6_row95_col10 {
#   background-color: #b93d02;
#   color: #f1f1f1;
# }
# #T_355c6_row2_col11 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_355c6_row3_col9 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_355c6_row3_col11 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_355c6_row4_col9 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_355c6_row4_col10, #T_355c6_row29_col10, #T_355c6_row41_col10, #T_355c6_row73_col10, #T_355c6_row78_col10, #T_355c6_row107_col10 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_355c6_row4_col11, #T_355c6_row5_col11, #T_355c6_row6_col11 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_355c6_row5_col9 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_355c6_row5_col10, #T_355c6_row9_col10, #T_355c6_row16_col10, #T_355c6_row40_col10, #T_355c6_row57_col10, #T_355c6_row70_col10, #T_355c6_row104_col10 {
#   background-color: #e05206;
#   color: #f1f1f1;
# }
# #T_355c6_row6_col9 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_355c6_row7_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_355c6_row7_col10, #T_355c6_row10_col10, #T_355c6_row17_col10, #T_355c6_row35_col10, #T_355c6_row49_col10, #T_355c6_row79_col10, #T_355c6_row101_col10 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_355c6_row7_col11 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_355c6_row8_col9, #T_355c6_row21_col9, #T_355c6_row44_col9 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_355c6_row8_col10, #T_355c6_row13_col10, #T_355c6_row14_col10, #T_355c6_row15_col10, #T_355c6_row32_col10, #T_355c6_row77_col10 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_355c6_row8_col11 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_355c6_row9_col9 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_355c6_row9_col11 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_355c6_row10_col9 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_355c6_row10_col11, #T_355c6_row11_col11 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_355c6_row11_col9 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_355c6_row11_col10, #T_355c6_row21_col10, #T_355c6_row27_col10, #T_355c6_row36_col10, #T_355c6_row83_col10, #T_355c6_row91_col10, #T_355c6_row100_col10, #T_355c6_row113_col10 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_355c6_row12_col9 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_355c6_row12_col10, #T_355c6_row22_col10, #T_355c6_row38_col10, #T_355c6_row42_col10, #T_355c6_row48_col10, #T_355c6_row69_col10, #T_355c6_row82_col10 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_355c6_row12_col11 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_355c6_row13_col9 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_355c6_row13_col11 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_355c6_row14_col9, #T_355c6_row15_col9, #T_355c6_row62_col9 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_355c6_row14_col11, #T_355c6_row15_col11 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_355c6_row16_col9 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_355c6_row16_col11 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_355c6_row17_col9, #T_355c6_row29_col9 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_355c6_row17_col11 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_355c6_row18_col9 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_355c6_row18_col11, #T_355c6_row19_col11 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_355c6_row19_col9 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_355c6_row19_col10, #T_355c6_row23_col10, #T_355c6_row26_col10, #T_355c6_row63_col10, #T_355c6_row67_col10, #T_355c6_row68_col10, #T_355c6_row75_col10, #T_355c6_row80_col10 {
#   background-color: #f77a27;
#   color: #f1f1f1;
# }
# #T_355c6_row20_col9, #T_355c6_row74_col9 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_355c6_row20_col11 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_355c6_row21_col11, #T_355c6_row22_col11 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_355c6_row22_col9 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_355c6_row23_col9, #T_355c6_row52_col9 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_355c6_row23_col11 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_355c6_row24_col9 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_355c6_row24_col10, #T_355c6_row43_col10, #T_355c6_row46_col10, #T_355c6_row88_col10, #T_355c6_row92_col10, #T_355c6_row94_col10, #T_355c6_row99_col10, #T_355c6_row108_col10 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_355c6_row24_col11 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_355c6_row25_col9 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_355c6_row25_col10, #T_355c6_row53_col10, #T_355c6_row59_col10, #T_355c6_row90_col10, #T_355c6_row102_col10, #T_355c6_row110_col10, #T_355c6_row112_col10 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_355c6_row25_col11 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_355c6_row26_col9 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_355c6_row26_col11 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_355c6_row27_col9, #T_355c6_row46_col9 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_355c6_row27_col11 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_355c6_row28_col9 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_355c6_row28_col10, #T_355c6_row34_col10, #T_355c6_row55_col10, #T_355c6_row61_col10, #T_355c6_row65_col10, #T_355c6_row72_col10, #T_355c6_row86_col10, #T_355c6_row87_col10 {
#   background-color: #e65a0b;
#   color: #f1f1f1;
# }
# #T_355c6_row28_col11, #T_355c6_row29_col11 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_355c6_row30_col9 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_355c6_row30_col10, #T_355c6_row45_col10, #T_355c6_row62_col10, #T_355c6_row71_col10, #T_355c6_row97_col10, #T_355c6_row103_col10, #T_355c6_row111_col10, #T_355c6_row115_col10 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_355c6_row30_col11 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_355c6_row31_col9 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_355c6_row31_col11 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_355c6_row32_col9, #T_355c6_row37_col9 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_355c6_row32_col11, #T_355c6_row33_col11 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_355c6_row33_col9, #T_355c6_row39_col9, #T_355c6_row84_col9 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_355c6_row34_col9 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_355c6_row34_col11 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_355c6_row35_col9, #T_355c6_row42_col9 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_355c6_row35_col11, #T_355c6_row36_col11 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_355c6_row36_col9 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_355c6_row37_col11 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_355c6_row38_col9 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_355c6_row38_col11 {
#   background-color: #9ad587;
#   color: #000000;
# }
