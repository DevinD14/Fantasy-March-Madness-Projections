# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import requests
from bs4 import BeautifulSoup
import time
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\devin\AppData\Local\Temp\ipykernel_37196\1361108272.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
# Fantasy scoring weights
SCORING = {
    'PTS': 1.0,   # Points per game
    'REB': 1.0,   # Total rebounds per game
    'AST': 1.0,   # Assists per game
    # Uncomment to add more categories:
    # 'STL': 2.0,
    # 'BLK': 2.0,
    # '3PM': 0.5,
}

# Path to your Monte Carlo CSV/Excel file
# Expected format: two columns — 'Team' and 'ExpectedGames'
# Example row:  Duke, 3.4
MONTE_CARLO_FILE = 'expected_games.csv'

# Minimum minutes per game to include a player (filters walk-ons / bench warmers)
MIN_MPG = 10

# How many players to show in the final draft board
DRAFT_BOARD_SIZE = 12*12
