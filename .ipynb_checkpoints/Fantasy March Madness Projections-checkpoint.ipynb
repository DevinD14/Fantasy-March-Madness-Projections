# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
import re
from difflib import SequenceMatcher
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Fantasy scoring weights
scoring = {
    'PPG': 1.0,
    'RPG': 1.0,
    'APG': 1.0,
    # 'SPG': 2.0,
    # 'BPG': 2.0,
    # '3PM': 0.5,
}

# Player stats filename
stats_file = 'realgm_stats.csv'

# Path to your Monte Carlo CSV/Excel file
# Expected format: two columns — 'Team' and 'ExpectedGames'
monte_carlo_file = 'expected_games.csv'

# Minimum games and minutes per game to include a player
min_games = 5
min_mpg = 10

# How many players to show in the final draft board
draft_board_size = 150

# %%
# real GM team abbreviations mapped to team name
# add new entries as needed
realgm_abbrev = {
    'AIRF':   'Air Force',
    'ALA':    'Alabama',
    'ALCN':   'Alcorn State',
    'ALST':   'Alabama State',
    'AMER':   'American',
    'ARIZ':   'Arizona',
    'ARK':    'Arkansas',
    'ARST':   'Arkansas-Pine Bluff',
    'ASU':    'Arizona State',
    'AUB':    'Auburn',
    'BAY':    'Baylor',
    'BC':     'Boston College',
    'BCST':   'Bethune-Cookman',
    'BOIS':   'Boise State',
    'BRY':    'Bryant',
    'BUF':    'Buffalo',
    'BYU':    'BYU',
    'CHAT':   'Chattanooga',
    'CIN':    'Cincinnati',
    'CLEM':   'Clemson',
    'COLG':   'Colgate',
    'COLO':   'Colorado',
    'COPN':   'Coppin State',
    'COST':   'Colorado State',
    'CREI':   'Creighton',
    'CSU':    'Colorado State',
    'DAVI':   'Davidson',
    'DAY':    'Dayton',
    'DELT':   'Delaware State',
    'DRAKE':  'Drake',
    'DUKE':   'Duke',
    'ETSU':   'East Tennessee State',
    'FLA':    'Florida',
    'FLAM':   'Florida A&M',
    'FRES':   'Fresno State',
    'FURD':   'Fordham',
    'FURM':   'Furman',
    'GONZ':   'Gonzaga',
    'GRAM':   'Grambling',
    'GW':     'George Washington',
    'HAW':    'Hawaii',
    'HOUS':   'Houston',
    'HOW':    'Howard',
    'HP':     'High Point',
    'HPT':    'High Point',
    'IAST':   'Iowa State',
    'ILL':    'Illinois',
    'IND':    'Indiana',
    'IOWA':   'Iowa',
    'IWAST':  'Iowa State',
    'JKSN':   'Jackson State',
    'JMU':    'James Madison',
    'KAN':    'Kansas',
    'KANS':   'Kansas',
    'KAST':   'Kansas State',
    'KEN':    'Kentucky',
    'KU':     'Kansas',
    'LIB':    'Liberty',
    'LIP':    'Lipscomb',
    'LMU':    'Loyola Marymount',
    'LONG':   'Longwood',
    'LOU':    'Louisville',
    'LSU':    'LSU',
    'LVILL':  'Louisville',
    'MARQ':   'Marquette',
    'MCN':    'McNeese',
    'MD':     'Maryland',
    'MEM':    'Memphis',
    'MERR':   'Merrimack',
    'MICH':   'Michigan State',
    'MINN':   'Minnesota',
    'MISS':   'Ole Miss',
    'MIZ':    'Missouri',
    'MONT':   'Montana',
    'MORE':   'Morehead State',
    'MORG':   'Morgan State',
    'MSM':    "Mount St. Mary's",
    'MSST':   'Mississippi State',
    'MSU':    'Michigan State',
    'MVST':   'Mississippi Valley State',
    'MZZOU':  'Missouri',
    'NCAT':   'North Carolina A&T',
    'NCST':   'NC State',
    'ND':     'Notre Dame',
    'NEB':    'Nebraska',
    'NFST':   'Norfolk State',
    'NMST':   'New Mexico State',
    'NOVA':   'Villanova',
    'NW':     'Northwestern',
    'NWST':   'Northwestern',
    'OKLA':   'Oklahoma',
    'OKST':   'Oklahoma State',
    'ORAL':   'Oral Roberts',
    'ORE':    'Oregon',
    'OSU':    'Ohio State',
    'PACF':   'Pacific',
    'PENN':   'Penn State',
    'PEPP':   'Pepperdine',
    'PITT':   'Pittsburgh',
    'PORT':   'Portland',
    'PRST':   'Prairie View A&M',
    'PUR':    'Purdue',
    'PURD':   'Purdue',
    'RICH':   'Richmond',
    'RMU':    'Robert Morris',
    'RUTG':   'Rutgers',
    'SAMF':   'Samford',
    'SCST':   'South Carolina State',
    'SCU':    'Santa Clara',
    'SDST':   'San Diego State',
    'SDSU':   'San Diego State',
    'SEAT':   'Seattle',
    'SFU':    'Saint Francis',
    'SIUE':   'SIU Edwardsville',
    'SJST':   'San Jose State',
    'SMCA':   "Saint Mary's",
    'STMRY':  "Saint Mary's",
    'SUST':   'Southern',
    'SYRA':   'Syracuse',
    'TCU':    'TCU',
    'TENN':   'Tennessee',
    'TEX':    'Texas',
    'TROY':   'Troy',
    'TTU':    'Texas Tech',
    'TXAM':   'Texas A&M',
    'TXSO':   'Texas Southern',
    'TXST':   'Texas State',
    'TXTCH':  'Texas Tech',
    'UA':     'Alabama',
    'UCF':    'UCF',
    'UCI':    'UC Irvine',
    'UCLA':   'UCLA',
    'UCON':   'UConn',
    'UCSB':   'UC Santa Barbara',
    'UCSD':   'UC San Diego',
    'UGA':    'Georgia',
    'UK':     'Kentucky',
    'UNC':    'North Carolina',
    'UNLV':   'UNLV',
    'UNM':    'New Mexico',
    'UNR':    'Nevada',
    'USC':    'USC',
    'USD':    'San Diego',
    'USF':    'South Florida',
    'USU':    'Utah State',
    'UTAH':   'Utah',
    'U OF H': 'Houston',
    'U of H': 'Houston',
    'U OF T': 'Toledo',
    'U of T': 'Toledo',
    'UWISC':  'Wisconsin',
    'VAN':    'Vanderbilt',
    'VANDY':  'Vanderbilt',
    'VCU':    'VCU',
    'VILL':   'Villanova',
    'WASH':   'Washington',
    'WEST':   'Western Carolina',
    'WF':     'Wake Forest',
    'WIS':    'Wisconsin',
    'WOF':    'Wofford',
    'WSU':    'Washington State',
    'WVU':    'West Virginia',
    'WYO':    'Wyoming',
    'XAV':    'Xavier',
    'YALE':   'Yale',
    'ZAGS':   'Gonzaga',
}

# %%
with open(stats_file, 'r', encoding='utf-8-sig') as f:
    first_line = f.readline()
delimiter = '\t' if first_line.count('\t') > first_line.count(',') else ','

raw = pd.read_csv(stats_file, sep=delimiter, dtype=str)
raw.columns = raw.columns.str.strip()

raw = raw.loc[:, ~raw.columns.str.match(r'^(Unnamed|#|Rank|Rk)$', case=False)]

col_map = {
    'G': 'GP', 'MIN': 'MPG', 'PTS': 'PPG', 'REB': 'RPG', 'TRB': 'RPG',
    'AST': 'APG', 'STL': 'SPG', 'BLK': 'BPG', '3P': '3PM',
}
raw = raw.rename(columns={c: col_map[c] for c in raw.columns if c in col_map})

if 'Player' in raw.columns:
    raw = raw[~raw['Player'].astype(str).str.strip().isin(['Player', '#', 'Rank', ''])]

for col in [c for c in raw.columns if c not in ('Player', 'Team')]:
    raw[col] = pd.to_numeric(raw[col], errors='coerce')

raw['Player'] = raw['Player'].astype(str).str.strip()
raw['Team'] = raw['Team'].astype(str).str.strip()
raw.dropna(subset=['Player', 'Team'], inplace=True)
raw.drop_duplicates(subset=['Player', 'Team'], inplace=True)
raw.reset_index(drop=True, inplace=True)

print(f'{len(raw):,} players loaded')
# Out:
# 2,583 players loaded

# %%
abbrev_ci = {k.upper(): v for k, v in realgm_abbrev.items()}
raw['team_full'] = raw['Team'].str.upper().map(abbrev_ci)

unknown = raw[raw['team_full'].isna()]['Team'].unique()
if len(unknown) > 0:
    print(f'{len(unknown)} unknown abbreviation(s) — add to realgm_abbrev:')
    for abbr in sorted(unknown):
        count = (raw['Team'] == abbr).sum()
        
else:
    print('all abbreviations resolved')

raw = raw.rename(columns={'Team': 'team_abbrev'})
raw['Team'] = raw['team_full'].fillna(raw['team_abbrev'])
raw.drop(columns='team_full', inplace=True)

raw[['Player', 'team_abbrev', 'Team']].head()
# Out:
# 285 unknown abbreviation(s) — add to realgm_abbrev:
#               Player team_abbrev           Team
# 0     Daeshun Ruffin        JKSN  Jackson State
# 1      A.J. Dybantsa         BYU            BYU
# 2       Jordan Riley        ECAR           ECAR
# 3  Darius Acuff, Jr.         ARK       Arkansas
# 4       Dontae Horne       PVAMU          PVAMU

# %%
def load_mc(path):
    mc = pd.read_excel(path) if path.lower().endswith(('xlsx', 'xls')) else pd.read_csv(path)
    mc.columns = mc.columns.str.strip()
    remap = {}
    for c in mc.columns:
        cl = c.lower().replace(' ', '_')
        if cl in ('team', 'school', 'program'):
            remap[c] = 'Team'
        elif cl in ('expected_games', 'exp_games', 'expectedgames', 'games', 'avg_games', 'projected_games'):
            remap[c] = 'ExpectedGames'
        elif cl in ('seed', 'seeding'):
            remap[c] = 'Seed'
    mc = mc.rename(columns=remap)
    for req in ('Team', 'ExpectedGames'):
        if req not in mc.columns:
            raise ValueError(f"missing column '{req}', found: {mc.columns.tolist()}")
    mc['ExpectedGames'] = pd.to_numeric(mc['ExpectedGames'], errors='coerce')
    mc['Team'] = mc['Team'].astype(str).str.strip()
    return mc

def normalize(name):
    name = re.sub(r'[^a-z0-9 ]', ' ', name.lower())
    return re.sub(r'\s+', ' ', name).strip()

mc_df = load_mc(monte_carlo_file)
print(f'{len(mc_df)} teams  |  xGames range: {mc_df.ExpectedGames.min():.2f} – {mc_df.ExpectedGames.max():.2f}')

expanded_teams = list(raw['Team'].unique())
expanded_lower = {t.lower(): t for t in expanded_teams}
expanded_norm  = {normalize(t): t for t in expanded_teams}

auto_fixed = {}
still_missing = []

for team in mc_df['Team']:
    if team.lower() in expanded_lower:
        if expanded_lower[team.lower()] != team:
            auto_fixed[team] = expanded_lower[team.lower()]
    elif normalize(team) in expanded_norm:
        auto_fixed[team] = expanded_norm[normalize(team)]
    else:
        still_missing.append(team)

if auto_fixed:
    mc_df['Team'] = mc_df['Team'].replace(auto_fixed)
    print(f'\nauto-resolved {len(auto_fixed)} name difference(s):')
    for old, new in auto_fixed.items():
        print(f'  "{old}" → "{new}"')

if still_missing:
    print(f'\ncould not match {len(still_missing)} team(s):')
    for t in still_missing:
        scored = sorted([(SequenceMatcher(None, normalize(t), normalize(e)).ratio(), e) for e in expanded_teams], reverse=True)[:3]
        sugg = [f'"{e}" ({r:.2f})' for r, e in scored if r > 0.5]
        print(f'  "{t}" → suggestions: {sugg or "none"}')
    print('\nadd the abbrev to realgm_abbrev and re-run')
else:
    print('\nall MC teams matched')
# Out:
# 64 teams  |  xGames range: 1.00 – 4.50
#
# auto-resolved 1 name difference(s):
#   "Omaha" → "OMAHA"
#
# could not match 22 team(s):
#   "Alabama State" → suggestions: ['"Oklahoma State" (0.74)', '"Alabama" (0.70)', '"Arizona State" (0.62)']
#   "Texas A&M" → suggestions: ['"TEXAS" (0.71)', '"Texas State" (0.70)', '"Texas Tech" (0.63)']
#   "Michigan" → suggestions: ['"Michigan State" (0.73)', '"WICHI" (0.62)', '"EMICH" (0.62)']
#   "Mississippi" → suggestions: ['"Missouri" (0.53)']
#   "Bryant" → suggestions: ['"BRYNT" (0.91)', '"BRWN" (0.60)', '"LBRTY" (0.55)']
#   "Norfolk State" → suggestions: ['"Ohio State" (0.70)', '"NC State" (0.67)', '"Penn State" (0.61)']
#   "Connecticut" → suggestions: none
#   "Maryland" → suggestions: ['"MAN" (0.55)']
#   "Grand Canyon" → suggestions: none
#   "Memphis" → suggestions: ['"MEMP" (0.73)', '"UMES" (0.55)', '"LEHI" (0.55)']
#   "Colorado State" → suggestions: ['"Colorado" (0.73)', '"Oklahoma State" (0.71)', '"Ohio State" (0.67)']
#   "UNC Wilmington" → suggestions: ['"UC Irvine" (0.52)', '"Creighton" (0.52)', '"George Washington" (0.52)']
#   "St. John's" → suggestions: ['"STONE" (0.57)', '"STJOE" (0.57)', '"SETON" (0.57)']
#   "Mount St Mary's" → suggestions: ['"Saint Mary\'s" (0.67)']
#   "Mississippi State" → suggestions: ['"Michigan State" (0.58)', '"Penn State" (0.52)', '"Ohio State" (0.52)']
#   "Baylor" → suggestions: ['"BAYL" (0.80)', '"UALR" (0.60)', '"BTLR" (0.60)']
#   "Arizona" → suggestions: ['"IONA" (0.73)', '"Arizona State" (0.70)', '"ARZ" (0.60)']
#   "Akron" → suggestions: ['"AKR" (0.75)', '"Dayton" (0.55)', '"Auburn" (0.55)']
#   "Oregon" → suggestions: ['"OREG" (0.80)', '"Creighton" (0.67)', '"ELON" (0.60)']
#   "Liberty" → suggestions: ['"LBRTY" (0.83)']
#   "McNeese State" → suggestions: ['"Texas State" (0.67)', '"NC State" (0.67)', '"Michigan State" (0.67)']
#   "Wofford" → suggestions: ['"WOFF" (0.73)', '"FORD" (0.73)', '"Samford" (0.57)']
#
# add the abbrev to realgm_abbrev and re-run

# %%
df = raw.copy()

if 'MPG' in df.columns:
    df = df[df['MPG'] >= min_mpg]
if 'GP' in df.columns:
    df = df[df['GP'] >= min_games]

tourney_teams = set(mc_df['Team'].str.lower())
df['_key'] = df['Team'].str.lower().str.strip()
tourney = df[df['_key'].isin(tourney_teams)].drop(columns='_key').copy()

print(f'{len(raw):,} → {len(df):,} after stat filters → {len(tourney):,} tournament players across {tourney["Team"].nunique()} teams')

empty = [t for t in mc_df['Team'] if t.lower() not in set(tourney['Team'].str.lower())]
if empty:
    print(f'\nno players matched for: {empty}')
    print('probably still a name mismatch — check cell 6')

tourney.head(5)
# Out:
# 2,583 → 2,513 after stat filters → 293 tournament players across 42 teams
#
# no players matched for: ['Alabama State', 'Texas A&M', 'Michigan', 'Mississippi', 'Bryant', 'Norfolk State', 'Connecticut', 'Maryland', 'Grand Canyon', 'Memphis', 'Colorado State', 'UNC Wilmington', "St. John's", "Mount St Mary's", 'Mississippi State', 'Baylor', 'Arizona', 'Akron', 'Oregon', 'Liberty', 'McNeese State', 'Wofford']
# probably still a name mismatch — check cell 6
#                Player team_abbrev  GP   MPG   PPG  FGM   FGA    FG%  3:00 PM  \
# 1       A.J. Dybantsa         BYU  18  36.3  25.9  8.9  18.9  0.471      1.8
# 3   Darius Acuff, Jr.         ARK  17  36.5  24.8  8.5  17.4  0.492      2.5
# 15     Cameron Boozer        DUKE  18  33.9  22.7  7.9  13.4  0.593      1.6
# 17        J.T. Toppin       TXTCH  13  35.7  22.6  9.6  17.8  0.541      0.9
# 25         Graham Ike        ZAGS  15  32.3  21.9  8.9  14.5  0.613      1.0
#
#     3PA  ...    FT%  ORB  DRB   RPG  APG  SPG  BPG  TOV   PF        Team
# 1   5.2  ...  0.740  1.3  5.1   6.4  3.8  0.8  0.3  3.3  1.5         BYU
# 3   5.7  ...  0.826  0.4  2.6   3.0  6.6  0.7  0.4  2.1  1.5    Arkansas
# 15  3.5  ...  0.795  3.4  6.9  10.3  3.9  1.6  0.2  2.3  1.3        Duke
# 17  2.6  ...  0.780  3.8  7.3  11.1  2.4  1.5  1.8  2.3  2.5  Texas Tech
# 25  2.7  ...  0.762  2.3  5.9   8.2  2.1  1.0  1.0  2.0  2.6     Gonzaga
#
# [5 rows x 23 columns]

# %%
missing = [s for s in scoring if s not in tourney.columns]
if missing:
    raise ValueError(f'scoring columns not in data: {missing}')

tourney['FPPG'] = tourney.apply(
    lambda r: sum(float(r.get(s, 0) or 0) * w for s, w in scoring.items()), axis=1
).round(2)

print(f'formula: {" + ".join(f"{w}×{s}" for s, w in scoring.items())}')
print()
cols = ['Player', 'Team', 'GP', 'MPG'] + list(scoring.keys()) + ['FPPG']
tourney.nlargest(10, 'FPPG')[[c for c in cols if c in tourney.columns]]
# Out:
# formula: 1.0×PPG + 1.0×RPG + 1.0×APG
#                       Player            Team  GP   MPG   PPG   RPG  APG  FPPG
# 15            Cameron Boozer            Duke  18  33.9  22.7  10.3  3.9  36.9
# 1              A.J. Dybantsa             BYU  18  36.3  25.9   6.4  3.8  36.1
# 17               J.T. Toppin      Texas Tech  13  35.7  22.6  11.1  2.4  36.1
# 3          Darius Acuff, Jr.        Arkansas  17  36.5  24.8   3.0  6.6  34.4
# 25                Graham Ike         Gonzaga  15  32.3  21.9   8.2  2.1  32.2
# 53              Caleb Wilson  North Carolina  11  33.5  20.1   7.7  3.1  30.9
# 28              Tyler Tanner      Vanderbilt  18  36.2  21.5   3.4  5.5  30.4
# 132  Christian Anderson, Jr.      Texas Tech  17  39.2  18.1   3.8  8.3  30.2
# 47             Keyshawn Hall          Auburn  17  34.1  20.6   6.1  2.8  29.5
# 43                 Nick Boyd       Wisconsin  20  32.9  20.8   3.9  4.5  29.2

# %%
mc_m = mc_df.copy()
mc_m['_key'] = mc_m['Team'].str.lower().str.strip()
tourney['_key'] = tourney['Team'].str.lower().str.strip()
seed_cols = ['Seed'] if 'Seed' in mc_m.columns else []

proj = tourney.merge(
    mc_m[['_key', 'ExpectedGames'] + seed_cols], on='_key', how='left'
).drop(columns='_key')

proj['ProjectedFP'] = (proj['FPPG'] * proj['ExpectedGames']).round(2)
print(f'{len(proj)} players with projections')
proj[['Player', 'Team', 'FPPG', 'ExpectedGames', 'ProjectedFP']].head(5)
# Out:
# 293 players with projections
#               Player        Team  FPPG  ExpectedGames  ProjectedFP
# 0      A.J. Dybantsa         BYU  36.1          2.112        76.24
# 1  Darius Acuff, Jr.    Arkansas  34.4          1.498        51.53
# 2     Cameron Boozer        Duke  36.9          4.425       163.28
# 3        J.T. Toppin  Texas Tech  36.1          3.292       118.84
# 4         Graham Ike     Gonzaga  32.2          2.212        71.23

# %%
cols = (
    (['Seed'] if 'Seed' in proj.columns else []) +
    ['Player', 'Team', 'team_abbrev', 'GP', 'MPG'] +
    list(scoring.keys()) +
    ['FPPG', 'ExpectedGames', 'ProjectedFP']
)
cols = [c for c in cols if c in proj.columns]

draft_board = (
    proj[cols]
    .sort_values('ProjectedFP', ascending=False)
    .head(draft_board_size)
    .reset_index(drop=True)
)
draft_board.index += 1
draft_board.index.name = 'Rank'

fmt = {k: '{:.2f}' for k in ['FPPG', 'ExpectedGames', 'ProjectedFP'] if k in draft_board.columns}
styled = draft_board.style.set_caption('🏀 March Madness Fantasy Draft Board')
for col, cmap in [('ProjectedFP', 'YlGn'), ('FPPG', 'Blues'), ('ExpectedGames', 'Oranges')]:
    if col in draft_board.columns:
        styled = styled.background_gradient(subset=[col], cmap=cmap)
display(styled.format(fmt))
# Out:
# <style type="text/css">
# #T_85687_row0_col8 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_85687_row0_col9, #T_85687_row14_col9, #T_85687_row24_col9, #T_85687_row41_col9, #T_85687_row59_col9, #T_85687_row63_col9, #T_85687_row71_col9, #T_85687_row107_col9 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_85687_row0_col10 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_85687_row1_col8 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_85687_row1_col9, #T_85687_row7_col9, #T_85687_row13_col9, #T_85687_row18_col9, #T_85687_row42_col9, #T_85687_row65_col9, #T_85687_row81_col9 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_85687_row1_col10 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_85687_row2_col8, #T_85687_row26_col8 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_85687_row2_col9, #T_85687_row9_col9, #T_85687_row38_col9, #T_85687_row44_col9, #T_85687_row52_col9 {
#   background-color: #eb610f;
#   color: #f1f1f1;
# }
# #T_85687_row2_col10 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_85687_row3_col8, #T_85687_row134_col8 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_85687_row3_col9, #T_85687_row25_col9, #T_85687_row32_col9, #T_85687_row33_col9, #T_85687_row49_col9 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_85687_row3_col10 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_85687_row4_col8, #T_85687_row20_col8, #T_85687_row22_col8 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_85687_row4_col9, #T_85687_row15_col9, #T_85687_row16_col9, #T_85687_row27_col9, #T_85687_row29_col9, #T_85687_row87_col9, #T_85687_row97_col9 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_85687_row4_col10 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_85687_row5_col8 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_85687_row5_col9, #T_85687_row6_col9, #T_85687_row8_col9, #T_85687_row21_col9, #T_85687_row23_col9, #T_85687_row50_col9 {
#   background-color: #9f3303;
#   color: #f1f1f1;
# }
# #T_85687_row5_col10 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_85687_row6_col8, #T_85687_row19_col8 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_85687_row6_col10 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_85687_row7_col8, #T_85687_row57_col8, #T_85687_row111_col8 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_85687_row7_col10 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_85687_row8_col8, #T_85687_row99_col8 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_85687_row8_col10 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_85687_row9_col8 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_85687_row9_col10 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_85687_row10_col8 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_85687_row10_col9, #T_85687_row11_col9, #T_85687_row47_col9, #T_85687_row55_col9, #T_85687_row58_col9, #T_85687_row78_col9, #T_85687_row105_col9 {
#   background-color: #dd4d04;
#   color: #f1f1f1;
# }
# #T_85687_row10_col10 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_85687_row11_col8 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_85687_row11_col10 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_85687_row12_col8 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_85687_row12_col9, #T_85687_row34_col9, #T_85687_row39_col9, #T_85687_row82_col9, #T_85687_row103_col9, #T_85687_row110_col9, #T_85687_row142_col9 {
#   background-color: #f16813;
#   color: #f1f1f1;
# }
# #T_85687_row12_col10 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_85687_row13_col8, #T_85687_row14_col8, #T_85687_row27_col8, #T_85687_row109_col8 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_85687_row13_col10 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_85687_row14_col10, #T_85687_row15_col10 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_85687_row15_col8 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_85687_row16_col8 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_85687_row16_col10 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_85687_row17_col8, #T_85687_row35_col8 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_85687_row17_col9, #T_85687_row28_col9, #T_85687_row43_col9, #T_85687_row83_col9, #T_85687_row89_col9, #T_85687_row128_col9 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_85687_row17_col10 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_85687_row18_col8, #T_85687_row121_col8 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_85687_row18_col10, #T_85687_row19_col10 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_85687_row19_col9, #T_85687_row30_col9, #T_85687_row40_col9, #T_85687_row45_col9, #T_85687_row88_col9, #T_85687_row98_col9, #T_85687_row101_col9, #T_85687_row113_col9 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_85687_row20_col9, #T_85687_row54_col9, #T_85687_row73_col9, #T_85687_row85_col9, #T_85687_row102_col9, #T_85687_row132_col9 {
#   background-color: #fb8735;
#   color: #f1f1f1;
# }
# #T_85687_row20_col10 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_85687_row21_col8 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_85687_row21_col10, #T_85687_row22_col10 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_85687_row22_col9, #T_85687_row36_col9, #T_85687_row69_col9, #T_85687_row75_col9, #T_85687_row104_col9 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_85687_row23_col8, #T_85687_row79_col8, #T_85687_row143_col8 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_85687_row23_col10 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_85687_row24_col8, #T_85687_row95_col8 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_85687_row24_col10, #T_85687_row25_col10 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_85687_row25_col8, #T_85687_row92_col8 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_85687_row26_col9, #T_85687_row46_col9, #T_85687_row51_col9, #T_85687_row147_col9 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_85687_row26_col10 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_85687_row27_col10 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_85687_row28_col8, #T_85687_row77_col8 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_85687_row28_col10 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_85687_row29_col8, #T_85687_row54_col8 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_85687_row29_col10 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_85687_row30_col8, #T_85687_row70_col8 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_85687_row30_col10 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_85687_row31_col8 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_85687_row31_col9, #T_85687_row95_col9, #T_85687_row114_col9, #T_85687_row124_col9, #T_85687_row130_col9, #T_85687_row148_col9 {
#   background-color: #fdb77a;
#   color: #000000;
# }
# #T_85687_row31_col10 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_85687_row32_col8, #T_85687_row69_col8, #T_85687_row106_col8 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_85687_row32_col10 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_85687_row33_col8, #T_85687_row84_col8 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_85687_row33_col10 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_85687_row34_col8, #T_85687_row119_col8, #T_85687_row123_col8, #T_85687_row125_col8, #T_85687_row141_col8 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_85687_row34_col10 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_85687_row35_col9, #T_85687_row57_col9, #T_85687_row79_col9, #T_85687_row80_col9, #T_85687_row90_col9 {
#   background-color: #fdad69;
#   color: #000000;
# }
# #T_85687_row35_col10, #T_85687_row36_col10 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_85687_row36_col8 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_85687_row37_col8 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_85687_row37_col9, #T_85687_row68_col9, #T_85687_row84_col9, #T_85687_row120_col9, #T_85687_row127_col9 {
#   backgr
